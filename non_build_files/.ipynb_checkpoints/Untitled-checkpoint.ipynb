# %%
dm <- lm(Sepal.Width ~ Petal.Length,iris)

# %%
pred <- stats::predict(dm,iris)
obs <- iris[['Sepal.Width']]

residuals <- obs - pred

names(residuals) <- 1:length(residuals)

residuals
dm$residuals <- residuals
# Out:
#         1         2         3         4         5         6         7         8
# -14.96195 -11.88333 -19.03075 -14.91544 -19.07576 -17.90856 -16.92372 -17.08041
#         9        10        11        12        13        14        15        16
# -14.22617 -19.00454 -15.27314 -15.76996 -18.52051 -19.06820 -19.65775 -14.39334
#        17        18        19        20        21        22        23        24
# -15.71688 -14.73023 -16.04769 -14.82930 -16.33377 -15.75533 -15.35600 -16.53418
#        25        26        27        28        29        30        31        32
# -18.29255 -16.11451 -18.22435 -17.91247 -17.53527 -17.50616 -18.61615 -17.98897
#        33        34        35        36        37        38        39        40
# -17.21805 -14.14141 -17.26111 -20.72109 -14.91257 -17.45541 -22.57140 -16.86278
#        41        42        43        44        45        46        47        48
# -14.92489 -15.40718 -18.84350 -20.03901 -19.94225 -17.97869 -16.32468 -16.55695
#        49        50        51        52        53        54        55        56
# -17.61016 -18.40331 -19.28526 -15.54824 -21.84093 -18.45751 -15.99321 -18.01582
#        57        58        59        60        61        62        63        64
# -15.13966 -16.00794 -16.81022 -19.15953 -19.13699 -17.79979 -17.89523 -21.93712
#        65        66        67        68        69        70        71        72
# -18.77875 -12.95102 -17.37561 -13.95560 -19.43231 -16.09315 -14.48663 -19.82830
#        73        74        75        76        77        78        79        80
# -20.32781 -16.25816 -14.35818 -17.69959 -14.94720 -15.91261 -14.82654 -18.42159
#        81        82        83        84        85        86        87        88
# -18.49389 -17.82151 -16.31326 -16.07876 -18.48068 -17.58516 -16.66809 -14.81257
#        89        90        91        92        93        94        95        96
# -15.01892 -17.75401 -21.26695 -16.67669 -17.98412 -16.41747 -18.77100 -20.33313
#        97        98        99       100       101       102       103       104
# -17.58355 -18.93266 -22.10676 -19.43861 -18.29199 -18.05343 -16.11253 -18.73022
#       105       106       107       108       109       110       111       112
# -15.88938 -19.02596 -18.58278 -17.01998 -17.06963 -18.73796 -19.46516 -21.90143
#       113       114       115       116       117       118       119       120
# -18.23044 -16.28908 -17.95470 -17.10472 -17.56959 -15.80989 -15.44267 -18.00953
#       121       122       123       124       125       126       127       128
# -18.23289 -17.67338 -18.12830 -17.91180 -16.68078 -18.35817 -17.96687 -13.87181
#       129       130       131       132       133       134       135       136
# -17.06591 -15.58843 -15.21735 -12.32251 -19.19738 -17.10190 -17.26140 -17.15716
#       137       138       139       140       141       142       143       144
# -16.12561 -19.83196 -14.07799 -15.84386 -12.63821 -14.38541 -18.70514 -14.64392
#       145       146       147       148       149       150
# -15.03570 -18.15291 -16.98754 -15.47786 -17.88312 -13.96432

# %%
?predict
# Out:
# predict                 package:stats                  R Documentation
#
# s
#
# n:
#
#      ‘predict’ is a generic function for predictions from the results
#      of various model fitting functions.  The function invokes
#      particular _methods_ which depend on the ‘class’ of the first
#      argument.
#
# e:
#
#      predict (object, ...)
#
# s:
#
#   object: a model object for which prediction is desired.
#
#      ...: additional arguments affecting the predictions produced.
#
# s:
#
#      Most prediction methods which are similar to those for linear
#      models have an argument ‘newdata’ specifying the first place to
#      look for explanatory variables to be used for prediction.  Some
#      considerable attempts are made to match up the columns in
#      ‘newdata’ to those used for fitting, for example that they are of
#      comparable types and that any factors have the same level set in
#      the same order (or can be transformed to be so).
#
#      Time series prediction methods in package ‘stats’ have an argument
#      ‘n.ahead’ specifying how many time steps ahead to predict.
#
#      Many methods have a logical argument ‘se.fit’ saying if standard
#      errors are to returned.
#
# e:
#
#      The form of the value returned by ‘predict’ depends on the class
#      of its argument.  See the documentation of the particular methods
#      for details of what is produced by that method.
#
# s:
#
#      Chambers, J. M. and Hastie, T. J. (1992) _Statistical Models in
#      S_.  Wadsworth & Brooks/Cole.
#
# o:
#
#      ‘predict.glm’, ‘predict.lm’, ‘predict.loess’, ‘predict.nls’,
#      ‘predict.poly’, ‘predict.princomp’, ‘predict.smooth.spline’.
#
#      SafePrediction for prediction from (univariable) polynomial and
#      spline fits.
#
#      For time-series prediction, ‘predict.ar’, ‘predict.Arima’,
#      ‘predict.arima0’, ‘predict.HoltWinters’, ‘predict.StructTS’.
#
# s:
#
#      require(utils)
#
#      ## All the "predict" methods found
#      ## NB most of the methods in the standard packages are hidden.
#      ## Output will depend on what namespaces are (or have been) loaded.
#      ## IGNORE_RDIFF_BEGIN
#      for(fn in methods("predict"))
#         try({
#             f <- eval(substitute(getAnywhere(fn)$objs[[1]], list(fn = fn)))
#             cat(fn, ":\n\t", deparse(args(f)), "\n")
#             }, silent = TRUE)
#      ## IGNORE_RDIFF_END

# %%
iris[['Sepal.Width']]
# Out:
#   [1] 3.5 3.0 3.2 3.1 3.6 3.9 3.4 3.4 2.9 3.1 3.7 3.4 3.0 3.0 4.0 4.4 3.9 3.5
#  [19] 3.8 3.8 3.4 3.7 3.6 3.3 3.4 3.0 3.4 3.5 3.4 3.2 3.1 3.4 4.1 4.2 3.1 3.2
#  [37] 3.5 3.6 3.0 3.4 3.5 2.3 3.2 3.5 3.8 3.0 3.8 3.2 3.7 3.3 3.2 3.2 3.1 2.3
#  [55] 2.8 2.8 3.3 2.4 2.9 2.7 2.0 3.0 2.2 2.9 2.9 3.1 3.0 2.7 2.2 2.5 3.2 2.8
#  [73] 2.5 2.8 2.9 3.0 2.8 3.0 2.9 2.6 2.4 2.4 2.7 2.7 3.0 3.4 3.1 2.3 3.0 2.5
#  [91] 2.6 3.0 2.6 2.3 2.7 3.0 2.9 2.9 2.5 2.8 3.3 2.7 3.0 2.9 3.0 3.0 2.5 2.9
# [109] 2.5 3.6 3.2 2.7 3.0 2.5 2.8 3.2 3.0 3.8 2.6 2.2 3.2 2.8 2.8 2.7 3.3 3.2
# [127] 2.8 3.0 2.8 3.0 2.8 3.8 2.8 2.8 2.6 3.0 3.4 3.1 3.0 3.1 3.1 3.1 2.7 3.2
# [145] 3.3 3.0 2.5 3.0 3.4 3.0
